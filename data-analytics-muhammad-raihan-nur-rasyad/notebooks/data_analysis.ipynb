# %%
import json
import pandas as pd

# %% [markdown]
# #Data Cleaning

# %% [markdown]
# ### Extract and clean `books.json` data

# %%
#import file books.json
with open('books.json', 'r') as file:
    data = json.load(file)

#konversi ke dataframe pandas
df = pd.json_normalize(data['books'])
dfn = pd.DataFrame(df)
dfn
# Out:
#    id                                  title               author  \
# 0   1                       The Great Gatsby  F. Scott Fitzgerald
# 1   2                  To Kill a Mockingbird           Harper Lee
# 2   3                                   1984        George Orwell
# 3   4                    Pride and Prejudice          Jane Austen
# 4   5                 The Catcher in the Rye        J.D. Salinger
# 5   6  Harry Potter and the Sorcerer's Stone         J.K. Rowling
# 6   7                  The Lord of the Rings       J.R.R. Tolkien
# 7   8                                   Dune        Frank Herbert
#
#                                                cover  rating  pages  \
# 0  https://covers.openlibrary.org/b/id/12749894-L...     4.2    180
# 1  https://covers.openlibrary.org/b/id/12749895-L...     4.8    376
# 2  https://covers.openlibrary.org/b/id/12749896-L...     4.6    328
# 3  https://covers.openlibrary.org/b/id/12749897-L...     4.4    432
# 4  https://covers.openlibrary.org/b/id/12749898-L...     3.8    277
# 5  https://covers.openlibrary.org/b/id/12749899-L...     4.7    309
# 6  https://covers.openlibrary.org/b/id/12749900-L...     4.9   1216
# 7  https://covers.openlibrary.org/b/id/12749901-L...     4.3    688
#
#            genre        status
# 0        Classic          read
# 1        Fiction          read
# 2      Dystopian       reading
# 3        Romance  want-to-read
# 4  Coming-of-age          read
# 5        Fantasy          read
# 6        Fantasy  want-to-read
# 7         Sci-Fi       reading

# %%
#drop kolom cover dan status
dfn2 = dfn.drop(['cover', 'status'], axis=1)

dfn2
# Out:
#    id                                  title               author  rating  \
# 0   1                       The Great Gatsby  F. Scott Fitzgerald     4.2
# 1   2                  To Kill a Mockingbird           Harper Lee     4.8
# 2   3                                   1984        George Orwell     4.6
# 3   4                    Pride and Prejudice          Jane Austen     4.4
# 4   5                 The Catcher in the Rye        J.D. Salinger     3.8
# 5   6  Harry Potter and the Sorcerer's Stone         J.K. Rowling     4.7
# 6   7                  The Lord of the Rings       J.R.R. Tolkien     4.9
# 7   8                                   Dune        Frank Herbert     4.3
#
#    pages          genre
# 0    180        Classic
# 1    376        Fiction
# 2    328      Dystopian
# 3    432        Romance
# 4    277  Coming-of-age
# 5    309        Fantasy
# 6   1216        Fantasy
# 7    688         Sci-Fi

# %%
#cek missing value
pd.isna(dfn2).sum()
# Out:
# id        0
# title     0
# author    0
# rating    0
# pages     0
# genre     0
# dtype: int64

# %%
#cek duplikat
dfn2.duplicated().sum()
# Out:
# np.int64(0)

# %%
#merubah genre dan status menjadi data category
text_cols = ["title", "author"]
dfn2[text_cols] = dfn2[text_cols].astype("string")

# %%
#merubah genre menjadi data category
dfn2["genre"] = dfn2["genre"].astype("category")

# %%
#cek tipe data
dfn2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      8 non-null      int64
#  1   title   8 non-null      string
#  2   author  8 non-null      string
#  3   rating  8 non-null      float64
#  4   pages   8 non-null      int64
#  5   genre   8 non-null      category
# dtypes: category(1), float64(1), int64(2), string(2)
# memory usage: 816.0 bytes

# %%
#simpan cleaned data kedalam file csv
dfn2.to_csv("books_clean.csv", index=False)

# %% [markdown]
# ### Create sample user interaction data and generate reading progress data

# %%
import random
from datetime import datetime, timedelta

# %%
random.seed(5) #fixed random
users = range(0, 200)
df2 = []

for user in users:
   user = random.randint(1, 100) #random user
   book_id = random.randint(1, 8) #random book
   action = random.choice(["view", "search", "rate"]) #random action
   random_month = random.randint(1, 12) #random month
   timestamp = datetime(2025, random_month, 15, 10, 30) + timedelta(days=random.randint(0, 30), hours=random.randint(0, 23), minutes=random.randint(0, 59)) #random timestamp
   total_pages = dfn.loc[dfn["id"] == book_id, "pages"].values[0] #mengambil total buku
   pages_read = random.randint(1, total_pages) #random halaman buku yang sudah dibaca
   completion_rate = round(pages_read / total_pages, 2) #hitung completion rate
   df2.append({
            "user_id": user,
            "book_id": book_id,
            "action": action,
            "timestamp": timestamp.isoformat(),
            "pages_read": pages_read,
            "total_pages": total_pages,
            "completion_rate": completion_rate
        })
user_df = pd.DataFrame(df2)
user_df
# Out:
#      user_id  book_id  action            timestamp  pages_read  total_pages  \
# 0         80        5    rate  2025-07-11T09:23:00         272          277
# 1          4        8    view  2025-11-16T15:37:00         381          688
# 2         61        4  search  2025-09-19T04:45:00           7          432
# 3         94        4  search  2025-05-20T22:40:00         391          432
# 4         10        3    rate  2025-10-29T14:38:00           1          328
# ..       ...      ...     ...                  ...         ...          ...
# 195       69        4    rate  2025-05-06T15:56:00         283          432
# 196       33        6  search  2025-10-18T16:46:00         218          309
# 197       46        5  search  2025-12-08T06:35:00          60          277
# 198       89        2  search  2025-02-19T06:48:00         299          376
# 199       23        1    rate  2025-07-21T06:51:00          67          180
#
#      completion_rate
# 0               0.98
# 1               0.55
# 2               0.02
# 3               0.91
# 4               0.00
# ..               ...
# 195             0.66
# 196             0.71
# 197             0.22
# 198             0.80
# 199             0.37
#
# [200 rows x 7 columns]

# %%
selected_columns = ['user_id', 'book_id', 'action', 'timestamp']
user_interaction_df = user_df[selected_columns]
user_interaction_df
# Out:
#      user_id  book_id  action            timestamp
# 0         80        5    rate  2025-07-11T09:23:00
# 1          4        8    view  2025-11-16T15:37:00
# 2         61        4  search  2025-09-19T04:45:00
# 3         94        4  search  2025-05-20T22:40:00
# 4         10        3    rate  2025-10-29T14:38:00
# ..       ...      ...     ...                  ...
# 195       69        4    rate  2025-05-06T15:56:00
# 196       33        6  search  2025-10-18T16:46:00
# 197       46        5  search  2025-12-08T06:35:00
# 198       89        2  search  2025-02-19T06:48:00
# 199       23        1    rate  2025-07-21T06:51:00
#
# [200 rows x 4 columns]

# %%
user_interaction_df.to_csv("user_interaction.csv", index=False)

# %%
selected_columns2 = ['user_id', 'book_id', 'pages_read', 'total_pages',	'completion_rate']
progress_df = user_df[selected_columns2]
progress_df
# Out:
#      user_id  book_id  pages_read  total_pages  completion_rate
# 0         80        5         272          277             0.98
# 1          4        8         381          688             0.55
# 2         61        4           7          432             0.02
# 3         94        4         391          432             0.91
# 4         10        3           1          328             0.00
# ..       ...      ...         ...          ...              ...
# 195       69        4         283          432             0.66
# 196       33        6         218          309             0.71
# 197       46        5          60          277             0.22
# 198       89        2         299          376             0.80
# 199       23        1          67          180             0.37
#
# [200 rows x 5 columns]

# %%
progress_df.to_csv("reading_progress.csv", index=False)

# %% [markdown]
# # Data Transformation

# %% [markdown]
# ### Total books read by users

# %%
#melihat total buku yang dibaca oleh masing2 pengguna
user_metrics = user_df.groupby("user_id").agg(
    avg_completion=("completion_rate", "mean"),
    total_books=("book_id", "nunique")
).reset_index()

user_metrics
# Out:
#     user_id  avg_completion  total_books
# 0         1          0.4400            3
# 1         3          0.7975            4
# 2         4          0.6000            3
# 3         5          0.8300            1
# 4         6          0.6750            2
# ..      ...             ...          ...
# 81       94          0.6180            4
# 82       95          0.1700            1
# 83       97          0.3650            2
# 84       98          0.2600            1
# 85       99          0.2900            2
#
# [86 rows x 3 columns]

# %% [markdown]
# ### User segment

# %%
#melihat segementasi pembaca berdasarkan tiga kategori
user_df["segment"] = pd.cut(
    user_df["completion_rate"],
    bins=[-1, 0.3, 0.7, 1],
    labels=["Low Reader", "Moderate Reader", "High Reader"]
)
user_df
# Out:
#      user_id  book_id  action            timestamp  pages_read  total_pages  \
# 0         80        5    rate  2025-07-11T09:23:00         272          277
# 1          4        8    view  2025-11-16T15:37:00         381          688
# 2         61        4  search  2025-09-19T04:45:00           7          432
# 3         94        4  search  2025-05-20T22:40:00         391          432
# 4         10        3    rate  2025-10-29T14:38:00           1          328
# ..       ...      ...     ...                  ...         ...          ...
# 195       69        4    rate  2025-05-06T15:56:00         283          432
# 196       33        6  search  2025-10-18T16:46:00         218          309
# 197       46        5  search  2025-12-08T06:35:00          60          277
# 198       89        2  search  2025-02-19T06:48:00         299          376
# 199       23        1    rate  2025-07-21T06:51:00          67          180
#
#      completion_rate          segment
# 0               0.98      High Reader
# 1               0.55  Moderate Reader
# 2               0.02       Low Reader
# 3               0.91      High Reader
# 4               0.00       Low Reader
# ..               ...              ...
# 195             0.66  Moderate Reader
# 196             0.71      High Reader
# 197             0.22       Low Reader
# 198             0.80      High Reader
# 199             0.37  Moderate Reader
#
# [200 rows x 8 columns]
